# %%
import numpy as np
import matplotlib.pyplot as plt
# import numpy.fft as fft

# %%
num_frames = 100
timestep = 0.05
# timestep = 1
r_vals = np.linspace(0.0, 10.0, 501)
r_vals = r_vals[:-1]
# r_vals[0] = 1e-10
# M_vals = np.linspace(0, 25.0, len(r_vals)+1)
# M_vals = M_vals[:-1]
# M_vals[0] = 1e-10
t_vals = np.linspace(0.0, (num_frames)*timestep, num_frames+1)
t_vals = t_vals[1:]
# t_vals[0] = 1e-10
print(f"shape of r_vals : {r_vals.shape}")
# print(f"shape of M_vals : {M_vals.shape}")
print(f"shape of t_vals : {t_vals.shape}")
# print(r_vals)
# print(M_vals)
print(t_vals)
# Out:
# shape of r_vals : (500,)
# shape of M_vals : (500,)
# shape of t_vals : (100,)
# [0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7
#  0.75 0.8  0.85 0.9  0.95 1.   1.05 1.1  1.15 1.2  1.25 1.3  1.35 1.4
#  1.45 1.5  1.55 1.6  1.65 1.7  1.75 1.8  1.85 1.9  1.95 2.   2.05 2.1
#  2.15 2.2  2.25 2.3  2.35 2.4  2.45 2.5  2.55 2.6  2.65 2.7  2.75 2.8
#  2.85 2.9  2.95 3.   3.05 3.1  3.15 3.2  3.25 3.3  3.35 3.4  3.45 3.5
#  3.55 3.6  3.65 3.7  3.75 3.8  3.85 3.9  3.95 4.   4.05 4.1  4.15 4.2
#  4.25 4.3  4.35 4.4  4.45 4.5  4.55 4.6  4.65 4.7  4.75 4.8  4.85 4.9
#  4.95 5.  ]

# %%
# s_vals = np.linspace(0.0, 2*np.pi, 101)
s_vals = np.linspace(1.0, 5.0, 101)
s_vals = s_vals[:-1]
# s_vals[0] = 1e-10 # set s=0 to a small value
# print(s_vals)

# %%
# write code for fourier transform of G_pred in r to get G_pred_k(t, k)
dk = 1/(r_vals[-1]-r_vals[0])
# we need only the positive k values
k_vals = np.linspace(0.0, np.pi*dk, (r_vals.shape[0]))
# k_vals = np.linspace(-np.pi*dk, np.pi*dk, (r_vals.shape[0]))
# k_vals = np.linspace(-np.pi/dk, np.pi/dk, r_vals.shape[0])
# print(k_vals)
print(k_vals.shape)
# Out:
# (500,)

# %%
num_alphas = 10
alphlowlim = 0.0
alphhighlim = 0.9
num_ds = 50
dlowlim = 0.0
dhighlim = 5.0

# %%
alpha_vals = np.linspace(alphlowlim, alphhighlim, num_alphas)
# alpha_vals[0] = 1e-10 # set alpha=0 to a small value
# alpha_vals = np.ones(num_alphas)*0.5
print(alpha_vals)

d_vals = np.linspace(dlowlim, dhighlim, num_ds+1)
d_vals = d_vals[:-1]
# d_vals[0] = 1e-10 # set d=0 to a small value
# d_vals = np.ones(num_ds)*2.0
print(d_vals)

# print the shape of the data
print(f"shape of alpha_vals : {alpha_vals.shape}")
print(f"shape of d_vals : {d_vals.shape}")
# Out:
# [0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5]
# [1.0e-10 1.0e-01 2.0e-01 3.0e-01 4.0e-01 5.0e-01 6.0e-01 7.0e-01 8.0e-01
#  9.0e-01 1.0e+00 1.1e+00 1.2e+00 1.3e+00 1.4e+00 1.5e+00 1.6e+00 1.7e+00
#  1.8e+00 1.9e+00 2.0e+00 2.1e+00 2.2e+00 2.3e+00 2.4e+00 2.5e+00 2.6e+00
#  2.7e+00 2.8e+00 2.9e+00 3.0e+00 3.1e+00 3.2e+00 3.3e+00 3.4e+00 3.5e+00
#  3.6e+00 3.7e+00 3.8e+00 3.9e+00 4.0e+00 4.1e+00 4.2e+00 4.3e+00 4.4e+00
#  4.5e+00 4.6e+00 4.7e+00 4.8e+00 4.9e+00]
# shape of alpha_vals : (10,)
# shape of d_vals : (50,)

# %%
# load Z
Z = np.load("Z.npy")
print(f"shape of Z : {Z.shape}")
# print(Z)
# Out:
# shape of Z : (100, 500, 10, 50)

# %%
# load u_pred
u = np.loadtxt("u.txt")
print(f"shape of u : {u.shape}")
# print(u_pred)
# Out:
# shape of u : (100, 500)

# %%
# plot the u_pred(s, k) for some s values
plt.figure(figsize=(10, 8))
plt.title("u(s, k) for some s values")
plt.xlabel("k")
plt.ylabel("u(s, k)")
plt.grid()
# plt.ylim(0)
for i in range(0, s_vals.shape[0], s_vals.shape[0]//10):
    if i == 0:
        continue
    plt.plot(k_vals, u[i, :], label=f"s = {s_vals[i]:.2f}")

plt.legend()
plt.show()

# %% [markdown]
# $P_s^{i+1}(\alpha, D) = P_s^i(\alpha, D) \int \frac{u(s,k)}{u_{pred}(s,k)}Z(s, k, \alpha, D)dk$
#
# where
#
# $u_{pred}(s,k) = \int \int P_s^{i}(\alpha, D) Z(s, k, \alpha, D) d\alpha dD$

# %%
u_pred = np.zeros(u.shape)
print(f"shape of u_pred : {u_pred.shape}")
# Out:
# shape of u_pred : (100, 500)

# %%
# initialize P_alpha_d
# P_alpha_d = np.ones((u.shape[0], num_alphas, num_ds))

# P_alpha_d = np.zeros((u.shape[0], num_alphas, num_ds))


# P_alpha_d[:, 2, 20] = 1

# initialize P_alpha_d to be a gaussian distribution with peak at (alpha, d) = (0.5, 2.5)
alpha0 = 0.4
d0 = 2.5
P_alpha_d = np.zeros((u.shape[0], num_alphas, num_ds))
for i in range(num_alphas):
    for j in range(num_ds):
        P_alpha_d[:, i, j] = np.exp(-((alpha_vals[i] - alpha0)**2 + (d_vals[j] - d0)**2) / 0.1)

# print(P_alpha_d)
# normalize P_alpha_d
P_alpha_d /= np.trapz(np.trapz(P_alpha_d, x=d_vals, axis=2), x=alpha_vals, axis=1)[:, None, None]

###### fixed alpha
# norm = (np.trapz(P_alpha_d, x=d_vals, axis=2))[:, :, None]
# P_alpha_d = P_alpha_d / norm
###### fixed alpha

# P_alpha_d = np.ones((num_alphas, num_ds))
print(f"shape of P_alpha_d : {P_alpha_d.shape}")

P_alpha_d_old = P_alpha_d.copy()
# Out:
# shape of P_alpha_d : (100, 10, 50)

# %%
def contour_plt(P_alpha_d, i=0, save=False, name=""):
    """
    Visualise P_alpha_d as a countour plot using contourf
    """
    # plot
    # rescale the y axis to be in the range of 0 to 2
    # rescale the x axis to be in the range of 0 to 1000
    plt.figure(figsize=(4, 4))
    x = np.linspace(dlowlim, dhighlim, num_ds)
    y = np.linspace(alphlowlim, alphhighlim, num_alphas)
    plt.contourf(x, y, P_alpha_d[i], 20, cmap='RdGy')
    plt.xlabel('d')
    plt.ylabel('alpha')
    plt.colorbar()
    if save:
        plt.savefig(name)
        plt.close()
    else:
        plt.show()

# %%
# visualize P_alpha_d inital
# for i in range(0, len(P_alpha_d), 5):
#     contour_plt(P_alpha_d, i)
contour_plt(P_alpha_d, (s_vals.shape[0]-1)//2)

# %%
def integ1(u_pred, P_alpha_d, alpha_vals, d_vals, k_vals, s_vals):
    # implement $u_{pred}(s,k) = \int \int P_s^{i}(\alpha, D) Z(\alpha, D, s, k) d\alpha dD$
    
    ############# correct but slow code with Z ind diff #############
    # for i in range(u_pred.shape[0]):
    #     for j in range(u_pred.shape[1]):
    #         u_pred[i, j] = np.trapz(np.trapz(P_alpha_d[i] * Z[:, :, i, j], d_vals, axis=1), alpha_vals, axis=0)
    ############# correct but slow code #############
    
    ############# vectorized code #############
    u_pred = np.trapz(np.trapz(P_alpha_d[:, None, :, :] * Z, d_vals, axis=3), alpha_vals, axis=2)
    ############# vectorized code #############
    
    ###### fixed alpha
    # u_pred = np.mean(np.trapz(P_alpha_d[:, None, :, :] * Z, d_vals, axis=3), axis=2)
    ###### fixed alpha

    # normalize u_pred for each s
    u_pred = u_pred / np.trapz(u_pred, k_vals, axis=1).reshape(-1, 1)

    return u_pred

def integ2(u, u_pred, P_alpha_d, alpha_vals, d_vals, k_vals, s_vals):
    # implement $P_s^{i+1}(\alpha, D) = P_s^i(\alpha, D) \int \frac{u(s,k)}{u_{pred}(s,k)}Z(\alpha, D, s, k)dk$

    # calculate ratio = u/u_pred
    u_pred[u_pred < 1e-7] = 0
    ratio = np.divide(u, u_pred, out=np.ones_like(u), where=u_pred != 0)
    print(f"mean ratio : {np.mean(ratio)}")
    # ratio = abs(ratio)

    ############# correct but slow code with Z ind diff #############
    # for i in range( P_alpha_d.shape[0]):
    #     for j in range(P_alpha_d.shape[1]):
    #         for k in range(P_alpha_d.shape[2]):
    #             P_alpha_d[i, j, k] *= np.trapz(ratio[i] * Z[j, k, i, :], k_vals)
    ############# correct but slow code #############
    
    ############# vectorized code #############
    P_alpha_d *= np.trapz(ratio[:, :, None, None] * Z, k_vals, axis=1)
    ############# vectorized code #############
                
    # normalize P_alpha_d for each s
    norm = np.trapz(np.trapz(P_alpha_d, x=d_vals, axis=2), x=alpha_vals, axis=1)[:, None, None]
    P_alpha_d = P_alpha_d / norm

    ###### fixed alpha
    # norm = (np.trapz(P_alpha_d, x=d_vals, axis=2))[:, :, None]
    # P_alpha_d = P_alpha_d / norm
    ###### fixed alpha

    return P_alpha_d

# %%
# iterate until delta is small enough
delta = 10000
num_iter = 0
# while delta > 1e-3 and num_iter < 1:
while delta > 1e-8:
    u_pred = integ1(u_pred, P_alpha_d, alpha_vals, d_vals, k_vals, s_vals)
    P_alpha_d = integ2(u, u_pred, P_alpha_d, alpha_vals, d_vals, k_vals, s_vals)
    delta = np.sum((P_alpha_d - P_alpha_d_old)**2)
    print(f"delta : {delta}")
    P_alpha_d_old = P_alpha_d.copy()
    num_iter += 1
    if num_iter % 100 == 0:
        contour_plt(P_alpha_d, (s_vals.shape[0]-1)//2, save=True, name=f"./P_alpha_d_img/contour_{num_iter}.png")
print(f"num_iter : {num_iter}")
# Out:
# mean ratio : 1.0007053717121666
# delta : 2.208965559902968e-05
# mean ratio : 1.0007053577031302
# delta : 2.2088979088589262e-05
# mean ratio : 1.0007053436944118
# delta : 2.2088302598824954e-05
# mean ratio : 1.0007053296860118
# delta : 2.208762612988772e-05
# mean ratio : 1.0007053156779295
# delta : 2.2086949681841794e-05
# mean ratio : 1.0007053016701655
# delta : 2.2086273254490478e-05
# mean ratio : 1.0007052876627198
# delta : 2.2085596847941014e-05
# mean ratio : 1.0007052736555921
# delta : 2.208492046223413e-05
# mean ratio : 1.0007052596487824
# delta : 2.208424409726944e-05
# mean ratio : 1.000705245642291
# delta : 2.2083567753108187e-05
# mean ratio : 1.0007052316361174
# delta : 2.2082891429763427e-05
# mean ratio : 1.000705217630262
# delta : 2.2082215127215842e-05
# mean ratio : 1.0007052036247246
# delta : 2.2081538845442825e-05
# mean ratio : 1.0007051896195052
# delta : 2.2080862584419364e-05
# mean ratio : 1.0007051756146041
# delta : 2.2080186344240862e-05
# mean ratio : 1.0007051616100209
# delta : 2.2079510124817215e-05
# mean ratio : 1.0007051476057554
# delta : 2.2078833926236216e-05
# mean ratio : 1.0007051336018085
# delta : 2.2078157748366623e-05
# mean ratio : 1.000705119598179
# delta : 2.2077481591364436e-05
# mean ratio : 1.0007051055948681
# delta : 2.2076805455083293e-05
# mean ratio : 1.0007050915918747
# delta : 2.207612933960556e-05
# mean ratio : 1.0007050775891997
# delta : 2.2075453244910693e-05
# mean ratio : 1.0007050635868426
# delta : 2.2074777171028408e-05
# mean ratio : 1.0007050495848036
# delta : 2.207410111794582e-05
# mean ratio : 1.0007050355830822
# delta : 2.207342508557071e-05
# mean ratio : 1.0007050215816788
# delta : 2.2072749074035857e-05
# mean ratio : 1.0007050075805934
# delta : 2.207207308330798e-05
# mean ratio : 1.000704993579826
# delta : 2.2071397113282466e-05
# mean ratio : 1.0007049795793768
# delta : 2.2070721164110864e-05
# mean ratio : 1.0007049655792453
# delta : 2.2070045235698048e-05
# mean ratio : 1.0007049515794315
# delta : 2.206936932803519e-05
# mean ratio : 1.000704937579936
# delta : 2.2068693441170038e-05
# mean ratio : 1.0007049235807584
# delta : 2.206801757512656e-05
# mean ratio : 1.0007049095818983
# delta : 2.2067341729803855e-05
# mean ratio : 1.0007048955833566
# delta : 2.206666590528094e-05
# mean ratio : 1.0007048815851323
# delta : 2.206599010155433e-05
# mean ratio : 1.0007048675872263
# delta : 2.206531431861228e-05
# mean ratio : 1.000704853589638
# delta : 2.2064638556411067e-05
# mean ratio : 1.0007048395923674
# delta : 2.2063962815021092e-05
# mean ratio : 1.000704825595415
# delta : 2.2063287094387098e-05
# mean ratio : 1.0007048115987802
# delta : 2.2062611394532542e-05
# mean ratio : 1.0007047976024632
# delta : 2.2061935715469058e-05
# mean ratio : 1.0006911780769252
# delta : 2.140705086091142e-05
# mean ratio : 1.0006911643900829
# delta : 2.1406395387280816e-05
# mean ratio : 1.0006911507035512
# delta : 2.1405739933937586e-05
# mean ratio : 1.0006911370173301
# delta : 2.1405084500813674e-05
# mean ratio : 1.0006911233314193
# delta : 2.1404429087929834e-05
# mean ratio : 1.0006911096458195
# delta : 2.1403773695319124e-05
# mean ratio : 1.0006910959605302
# delta : 2.14031183229424e-05
# mean ratio : 1.000691082275551
# delta : 2.140246297084152e-05
# mean ratio : 1.0006910685908827
# delta : 2.140180763896474e-05
# mean ratio : 1.0006910549065249
# delta : 2.1401152327353555e-05
# mean ratio : 1.0006910412224777
# delta : 2.140049703597618e-05
# mean ratio : 1.0006910275387404
# delta : 2.13998417648644e-05
# mean ratio : 1.000691013855314
# delta : 2.139918651396231e-05
# mean ratio : 1.000691000172198
# delta : 2.1398531283343844e-05
# mean ratio : 1.0006909864893927
# delta : 2.1397876072923575e-05
# mean ratio : 1.0006909728068976
# delta : 2.1397220882791016e-05
# mean ratio : 1.0006909591247126
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb Cell 16 line 7
#       <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> while delta > 1e-8:
#       <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     u_pred = integ1(u_pred, P_alpha_d, alpha_vals, d_vals, k_vals, s_vals)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     P_alpha_d = integ2(u, u_pred, P_alpha_d, alpha_vals, d_vals, k_vals, s_vals)
#       <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     delta = np.sum((P_alpha_d - P_alpha_d_old)**2)
#       <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     print(f"delta : {delta}")
#
# /home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb Cell 16 line 4
#      <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a> print(f"mean ratio : {np.mean(ratio)}")
#      <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a> # ratio = abs(ratio)
#      <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=30'>31</a>
#      <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=31'>32</a> ############# correct but slow code with Z ind diff #############
#    (...)
#      <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=37'>38</a>
#      <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=38'>39</a> ############# vectorized code #############
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=39'>40</a> P_alpha_d *= np.trapz(ratio[:, :, None, None] * Z, k_vals, axis=1)
#      <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=40'>41</a> ############# vectorized code #############
#      <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=41'>42</a>
#      <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=42'>43</a> # normalize P_alpha_d for each s
#    (...)
#      <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=45'>46</a>
#      <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=46'>47</a> ###### fixed alpha
#      <a href='vscode-notebook-cell://ssh-remote%2Bgnode039/home2/mkrishnapraneet/transcription-factor/fractional_vectorized.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=47'>48</a> norm = (np.trapz(P_alpha_d, x=d_vals, axis=2))[:, :, None]
#
# File ~/miniconda3/lib/python3.10/site-packages/numpy/lib/function_base.py:4978, in trapz(y, x, dx, axis)
#    4976 slice2[axis] = slice(None, -1)
#    4977 try:
# -> 4978     ret = (d * (y[tuple(slice1)] + y[tuple(slice2)]) / 2.0).sum(axis)
#    4979 except ValueError:
#    4980     # Operations didn't work, cast to ndarray
#    4981     d = np.asarray(d)
#
# File ~/miniconda3/lib/python3.10/site-packages/numpy/core/_methods.py:47, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
#      45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
# ---> 47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
#      49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      51 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#      52           initial=_NoValue, where=True):
#
# KeyboardInterrupt:

# %%
contour_plt(P_alpha_d, (s_vals.shape[0]-1)//2)
print(f"ratio = {np.mean(u/u_pred)}")
# Out:
# ratio = 1.000851528466922

# %%
for i in range(0, len(P_alpha_d), s_vals.shape[0]//10):
    contour_plt(P_alpha_d, i)
