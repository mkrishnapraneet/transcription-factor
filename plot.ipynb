# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# plot data from file for MSD (fort.9)

# load data from file
data = np.loadtxt('fort.9')

# shape of the data
print(data.shape)
# print(data)

# plot the data
plt.plot(data[:,0], data[:,1])
plt.title("Mean Square Displacement")
plt.xlabel("Lag Time (frames)")
plt.ylabel("MSD (pixels^2)")
# Out:
# (100, 2)
# Text(0, 0.5, 'MSD (pixels^2)')

# %%
# plot from fort.60
# load data from file
data = np.loadtxt('fort.60')

# shape of the data
print(data.shape)

# plot the data
plt.scatter(data[:,0], data[:,1])
# Out:
# (11091, 2)

# %%
# load data from file
for i in range(363, 364):
    data = np.loadtxt(f'fort.{i}')

    # shape of the data
    print(data.shape)
    # print(data)

    # plot the data
    plt.plot(data[:,0], data[:,1])
    # plt.title("Self Van Hove Correlation Function")
    # plt.show()
# Out:
# (500, 2)

# %%
# plot from fort.751
# load data from file
data = np.loadtxt('fort.751')
# data = np.loadtxt('fort.771')

# shape of the data
print(data.shape)

# plot the data
plt.plot(data[:,0], data[:,1])
# Out:
# (15000, 2)

# %%
# plot from fort.751
# load data from file
# data = np.loadtxt('fort.751')
data = np.loadtxt('fort.771')

# shape of the data
print(data.shape)

# plot the data
plt.plot(data[:,0], data[:,1])
# Out:
# (15000, 2)

# %%
# load data from file
# for i in range(363, 364):
for i in range(851, 853):
    data = np.loadtxt(f'fort.{i}')

    # shape of the data
    print(data.shape)
    # print(data)

    # plot the data
    if(i == 853):
        plt.plot(data[:,0], data[:,-1])
    else:
        plt.plot(data[:,0], data[:,1])
    plt.title("Self Van Hove Correlation Function")
    plt.show()
# Out:
# (500, 2)
# (500, 2)

# %%
# read data from fort.853
data = np.loadtxt('fort.853')

# plot the data
plt.plot(data[:,0], data[:,1])
plt.plot(data[:,0], data[:,2])
plt.xlim(0, 600)
plt.ylim(0, 6)
# Out:
# (0.0, 6.0)

# %%
# plot from fort.970
# load data from file
data = np.loadtxt('fort.970')

# shape of the data
print(data.shape)

# plot the data
plt.plot(data[:,0], data[:,1])
# Out:
# (632000, 2)

# %%
# plot from fort.2001
# load data from file
data = np.loadtxt('fort.2001')

# shape of the data
print(data.shape)

# plot the data
plt.plot(data[:,0], data[:,1])
# Out:
# (7, 2)

# %%
# plot from fort.2002
# load data from file
data = np.loadtxt('fort.2002')

# shape of the data
print(data.shape)

# plot the data
plt.plot(data[:,0], data[:,1])
# Out:
# (493, 2)

# %% [markdown]
# # #################
# my results from here on

# %%
# load data from P.txt
P = np.loadtxt('P.txt')

# shape of the data
print(P.shape)

num_frames = P.shape[0]
M_vals = np.linspace(0, 25.0, P.shape[1])
print(M_vals.shape)

# plot the data
for i in range(1, num_frames, 20):
    plt.plot(M_vals, P[i, :])    plt.plot(r_vals[:-1], van_hove[i, :] * 2 * np.pi * r_vals[1:])

    plt.title(f"P(M, t) for lag time = {i}")
    # plt.show()
# plt.show()
# Out:
#   Cell In[164], line 13
#     plt.plot(M_vals, P[i, :])    plt.plot(r_vals[:-1], van_hove[i, :] * 2 * np.pi * r_vals[1:])
#                                  ^
# SyntaxError: invalid syntax
